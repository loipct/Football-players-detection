# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import torch
use_cuda = torch.cuda.is_available()
print(use_cuda)
# Out:
# True

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 614.4/614.4 kB 12.8 MB/s eta 0:00:00
# ...

# %%
# %cd /content/drive/MyDrive/yolo
# Out:
# /content/drive/MyDrive/yolo

# %%
# !mkdir YOLOv8/Datasets/football-players_yolov8

# %%
# !unzip Dataset/football-players_yolov8.zip -d YOLOv8/Datasets/football-players_yolov8
# Out:
# Archive:  Dataset/football-players_yolov8.zip
#  extracting: YOLOv8/Datasets/README.dataset.txt
#  extracting: YOLOv8/Datasets/README.roboflow.txt
#  extracting: YOLOv8/Datasets/data.yaml
#    creating: YOLOv8/Datasets/test/
#    creating: YOLOv8/Datasets/test/images/
#  extracting: YOLOv8/Datasets/test/images/40cd38_7_6_png.rf.dc7957fcce915bc48188f18a7b19455b.jpg
#  extracting: YOLOv8/Datasets/test/images/42ba34_1_5_png.rf.927d602c034ce2997f58f62a7c1245ba.jpg
#  extracting: YOLOv8/Datasets/test/images/42ba34_5_5_png.rf.f691b18c36a92663c7241c99d4202bcc.jpg
#  extracting: YOLOv8/Datasets/test/images/4b770a_1_4_png.rf.8a0f6be9776a652d40938181f60b3a6c.jpg
#  extracting: YOLOv8/Datasets/test/images/4b770a_3_6_png.rf.f5d975605c1f73e1a95a1d8edc4ce5b1.jpg
#  extracting: YOLOv8/Datasets/test/images/573e61_1_9_png.rf.3e04feabb7fa88ed2691adcb5034e6ae.jpg
#  extracting: YOLOv8/Datasets/test/images/573e61_9_6_png.rf.f7756714cdfe79da92e3e99837b7b655.jpg
# ...

# %%
# %cd /content/drive/MyDrive/yolo/YOLOv8
# Out:
# /content/drive/MyDrive/yolo/YOLOv8

# %%
# !pwd
# Out:
# /content/drive/MyDrive/yolo/YOLOv8

# %%
from ultralytics import YOLO
! yolo task=detect \
mode=train \
model=yolov8n.pt \
data= /content/drive/MyDrive/yolo/YOLOv8/datasets/football-players_yolov8/data.yaml \
epochs=100 \
imgsz=640
# Out:
# Ultralytics YOLOv8.0.149 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
from ultralytics import YOLO

# Load a model
optimize_cpu = False
model = YOLO('runs/detect/train21/weights/best.pt')  # load a custom trained

# Export the model
model.export(format='onnx',optimize=optimize_cpu)
# Out:
# Ultralytics YOLOv8.0.149 🚀 Python-3.10.12 torch-2.0.1+cu118 CPU (Intel Xeon 2.00GHz)
# Model summary (fused): 168 layers, 3006428 parameters, 0 gradients
#
# PyTorch: starting from 'runs/detect/train21/weights/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 8, 8400) (6.0 MB)
# requirements: Ultralytics requirement ['onnx>=1.12.0'] not found, attempting AutoUpdate...
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.6/14.6 MB 110.9 MB/s eta 0:00:00
# ...
#
# requirements: AutoUpdate success ✅ 8.3s, installed 1 package: ['onnx>=1.12.0']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
#
# ONNX: starting export with onnx 1.14.0 opset 17...
# ONNX: export success ✅ 9.4s, saved as 'runs/detect/train21/weights/best.onnx' (11.7 MB)
#
# Export complete (11.2s)
# Results saved to /content/drive/MyDrive/yolo/YOLOv8/runs/detect/train21/weights
# Predict:         yolo predict task=detect model=runs/detect/train21/weights/best.onnx imgsz=640
# ...
